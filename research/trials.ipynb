# %%
print("hello")
# Out:
# hello

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
from dotenv import load_dotenv,dotenv_values
import os
from langchain_community.document_loaders import PyPDFDirectoryLoader

# %%
load_dotenv()
# Out:
# True

# %%
groq_api_key=os.getenv("groq_api_key")

# %%
os.environ["groq_api_key"]=groq_api_key

# %%
from langchain_community.document_loaders import CSVLoader,DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.output_parsers import StrOutputParser

# %%
def pdf_file_load(data):
    loader=DirectoryLoader(
        data,
        glob="*.csv",
        loader_cls=CSVLoader
    )
    document=loader.load()
    return document

# %%
extracted_load=pdf_file_load('data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 extracted_load=pdf_file_load('data')
#
# Cell In[15], line 7, in pdf_file_load(data)
#       1 def pdf_file_load(data):
#       2     loader=DirectoryLoader(
#       3         data,
#       4         glob="*.csv",
#       5         loader_cls=CSVLoader
#       6     )
# ----> 7     document=loader.load()
#       8     return document
#
# File ~/coding/sec/env/lib/python3.10/site-packages/langchain_community/document_loaders/directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File ~/coding/sec/env/lib/python3.10/site-packages/langchain_community/document_loaders/directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: 'data'
